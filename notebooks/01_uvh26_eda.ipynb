# %% [markdown]
# # UVH-26 Majority Voting EDA
# Run the audit and EDA commands from the repository root before opening this notebook. All tables and figures are generated from the pinned official annotation files. Image decoding and leakage checks are reported separately.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import display, Image
root = Path.cwd()
if root.name == "notebooks": root = root.parent
display(pd.read_csv(root / "reports/audit/split_summary.csv"))
display(pd.read_csv(root / "reports/tables/eda_class_distribution.csv"))

# %%
for name in ["class_distribution", "objects_per_image", "bbox_area_distribution", "object_center_heatmap"]:
    display(Image(filename=str(root / "reports/figures" / f"{name}.png")))
